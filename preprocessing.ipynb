# %% [markdown]
# # **ABOUT US**
#
# ## 1. Thông tin các thành viện trong nhóm
#
# |**STT**|**MSSV**|**Họ và tên**|**Email**|
# |---|-----------------------|--------|---------------------|
# |01|20120328|Hoàng Đức Nhật Minh|20120328@student.hcmus.edu.vn|
# |02|20120224|Trần Thị Mỹ Trinh|20120224@student.hcmus.edu.vn|
# |03|20120210|Trần Thị Kim Tiến|20120210@student.hcmus.edu.vn|
# |04|20120307|Phạm Gia Khiêm|20120307@student.hcmus.edu.vn|
# |05|20120231|Phan Huy Trường|20120231@student.hcmus.edu.vn|

# %% [markdown]
# ## 2. Phân chia công việc

# %% [markdown]
# #### **Giai đoạn 1**
# Trước khi thực hiện chọn ra mô hình tốt nhất, thì chúng em đã chia thành 2 nhóm để cùng thực hiện tiền xử lý, lựa chọn nhiều mô hình khác nhau theo cách khác nhau:
# - Nhóm 1, bao gồm các thành viên:
#   - Hoàng Đức Nhật Minh
#   - Trần Thị Mỹ Trinh
#   - Phạm Quốc Thái
# - Nhóm 2, bao gồm các thành viên:
#   - Phạm Gia Khiêm
#   - Trần Thị Kim Tiến
#   - Phan Huy Trường
#
# |**Tên công việc**|**Nội dung chi tiết**|**NHÓM 1**|**NHÓM 2**|
# |-------------------|-------------------------|--------------------------------|---------------------|
# |Phân tích dữ liệu||Hoàng Đức Nhật Minh|Phan Huy Trường|
# |Tiền xử lý dữ liệu||Hoàng Đức Nhật Minh <br /> Trần Thị Mỹ Trinh|Phạm Gia Khiêm <br /> Phan Huy Trường|
# |Chọn mô hình| 1. Decision tree <br /> 2. Linear regression <br /> 3. Rigde regression <br /> 4. Lasso regression <br /> 5. XGBoost <br /> 6. LightGBM <br /> 7. Bagging <br /> 8. Stacking| <br /> <br /> Phạm Quốc Thái <br /> Trần Thị Mỹ Trinh <br /> Phạm Quốc Thái <br /> Hoàng Đức Nhật Minh <br /> Hoàng Đức Nhật Minh <br /> <br />|Phạm Gia Khiêm <br /> Phạm Gia Khiêm <br /> Phan Huy Trường <br /> Phan Huy Trường<br />Trần Thị Kim Tiến <br /> Trần Thị Kim Tiến <br /> <br /> Phạm Gia Khiêm <br />|

# %% [markdown]
# #### **Giai đoạn 2**
# Sau giai đoạn 1, nhóm đã họp bàn và chọn ra phương pháp tiền xử lý hiệu quả nhất là của *NHÓM 1* và lựa chọn mô hình huấn luyện cho dữ liệu phù hợp nhất đó là các mô hình:
# - Ridge regression
# - Lasso regression
# - XGBoost
# - LightGBM
# - Bagging
# - Stacking
#
# Sau khi lựa chọn mô hình, thì nhóm bắt đầu phân chia tiếp công việc như sau:
#
# |**Tên công việc**|**Thành viên đảm nhiệm**|**Đánh giá**|
# |-------------------|-------------------------|---------------------|
# |Tìm hyperparameter cho các mô hình|Phạm Gia Khiêm <br /> Hoàng Đức Nhật Minh|100%|
# |Tìm hiểu Ridge <br /> Tìm hiểu Lasso|Phạm Quốc Thái <br /> Phan Huy Trường|100%|
# |Tìm hiểu XGBoost <br /> Tìm hiểu LightGBM|Trần Thị Kim Tiến|100%|
# |Làm slide thuyết trình|Trần Thị Mỹ Trinh <br /> Hoàng Đức Nhật Minh <br />Trần Thị Kim Tiến <br /> Phạm Gia Khiêm <br /> Phan Huy Trường <br /> Phạm Quốc Thái|100%|
# |Thuyết trình|Phạm Quốc Thái <br /> Trần Thị Kim Tiến|100%|

# %% [markdown]
# # **DATA PREPROCESSING**
#
# Quá trình tiền xử lý dữ liệu giá nhà trước khi thực hiện dự đoán giá nhà thông qua các mô hình hồi quy
#
# Github: https://github.com/hoangducnhatminh/predict-house-price-advanced.git

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats

from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# # 1. Exploratory Data Analysis

# %% [markdown]
# **Thông tin của 80 trường dữ liệu:**

# %% [markdown]
# - SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
# - MSSubClass: The building class
# - MSZoning: The general zoning classification
# - LotFrontage: Linear feet of street connected to property
# - LotArea: Lot size in square feet
# - Street: Type of road access

# %% [markdown]
# - Alley: Type of alley access
# - LotShape: General shape of property
# - LandContour: Flatness of the property
# - Utilities: Type of utilities available
# - LotConfig: Lot configuration
# - LandSlope: Slope of property
# - Neighborhood: Physical locations within Ames city limits
# - Condition1: Proximity to main road or railroad

# %% [markdown]
# - Condition2: Proximity to main road or railroad (if a second is present)
# - BldgType: Type of dwelling
# - HouseStyle: Style of dwelling
# - OverallQual: Overall material and finish quality
# - OverallCond: Overall condition rating
# - YearBuilt: Original construction date
# - YearRemodAdd: Remodel date
# - RoofStyle: Type of roof
# - RoofMatl: Roof material
# - Exterior1st: Exterior covering on house
# - Exterior2nd: Exterior covering on house (if more than one material)

# %% [markdown]
# - MasVnrType: Masonry veneer type
# - MasVnrArea: Masonry veneer area in square feet
# - ExterQual: Exterior material quality
# - ExterCond: Present condition of the material on the exterior
# - Foundation: Type of foundation
# - BsmtQual: Height of the basement
# - BsmtCond: General condition of the basement
# - BsmtExposure: Walkout or garden level basement walls
# - BsmtFinType1: Quality of basement finished area
# - BsmtFinSF1: Type 1 finished square feet
# - BsmtFinType2: Quality of second finished area (if present)

# %% [markdown]
# - BsmtFinSF2: Type 2 finished square feet
# - BsmtUnfSF: Unfinished square feet of basement area
# - TotalBsmtSF: Total square feet of basement area
# - Heating: Type of heating
# - HeatingQC: Heating quality and condition
# - CentralAir: Central air conditioning
# - Electrical: Electrical system
# - 1stFlrSF: First Floor square feet
# - 2ndFlrSF: Second floor square feet
# - LowQualFinSF: Low quality finished square feet (all floors)
# - GrLivArea: Above grade (ground) living area square feet
# - BsmtFullBath: Basement full bathrooms
# - BsmtHalfBath: Basement half bathrooms
# - FullBath: Full bathrooms above grade

# %% [markdown]
# - HalfBath: Half baths above grade
# - Bedroom: Number of bedrooms above basement level
# - Kitchen: Number of kitchens
# - KitchenQual: Kitchen quality
# - TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# - Functional: Home functionality rating
# - Fireplaces: Number of fireplaces
# - FireplaceQu: Fireplace quality
# - GarageType: Garage location
# - GarageYrBlt: Year garage was built
# - GarageFinish: Interior finish of the garage
# - GarageCars: Size of garage in car capacity
# - GarageArea: Size of garage in square feet
# - GarageQual: Garage quality

# %% [markdown]
# - GarageCond: Garage condition
# - PavedDrive: Paved driveway
# - WoodDeckSF: Wood deck area in square feet
# - OpenPorchSF: Open porch area in square feet
# - EnclosedPorch: Enclosed porch area in square feet
# - 3SsnPorch: Three season porch area in square feet
# - ScreenPorch: Screen porch area in square feet
# - PoolArea: Pool area in square feet
# - PoolQC: Pool quality
# - Fence: Fence quality
# - MiscFeature: Miscellaneous feature not covered in other categories
# - MiscVal: $Value of miscellaneous feature
# - MoSold: Month Sold
# - YrSold: Year Sold
# - SaleType: Type of sale
# - SaleCondition: Condition of sale

# %% [markdown]
# **Load data**

# %%
# Load data
train_data = pd.read_csv('train.csv', index_col='Id')
test_data = pd.read_csv('test.csv', index_col='Id')
train_data.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# Id
# ...

# %%
# Seperate features and target variable
X_train = train_data.drop(['SalePrice'], axis=1)
y = train_data.SalePrice

# %% [markdown]
# **Describe data**

# %%
print("Kích thước tập dữ liệu train: ", X_train.shape)
print("Kích thước tập dữ liệu test: ", test_data.shape)
# Out:
# Kích thước tập dữ liệu train:  (1460, 79)
# Kích thước tập dữ liệu test:  (1459, 79)

# %% [markdown]
# Tiếp theo, gộp 2 dữ liệu train và test lại, để lát tiền xử lý dữ liệu.

# %%
# Concatenate train and test data
X = pd.concat([X_train, test_data], axis=0)

# %% [markdown]
# Cả tập train và test đều có 79 trường dữ liệu độc lập, tập train có 1460 mẫu, tập test có 1459 mẫu.

# %%
numericalCols = list(train_data.select_dtypes(exclude='object').columns)
print(f"Có {len(numericalCols)} đặc trưng là thuộc numerical:\n", numericalCols)
# Out:
# Có 37 đặc trưng là thuộc numerical:
#  ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
categoricalCols = list(train_data.select_dtypes(include='object').columns)
print(f"Có {len(categoricalCols)} đặc trưng là thuộc categorical:\n", categoricalCols)
# Out:
# Có 43 đặc trưng là thuộc categorical:
#  ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %% [markdown]
# Đây là cấu trúc file nộp, sẽ có 2 cột, cột Id tương ứng với Id trong file test.csv, và giá nhà do mô hình dự đoán.

# %%
df_sub = pd.read_csv('sample_submission.csv')
df_sub.head(3)
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570

# %% [markdown]
# Xem thống kê mô tả của các trường dữ liệu. Ta thử xem thống kê mô tả của biến dự đoán SalePrice, không có dòng dữ liệu thiếu (count = 1460), giá trung bình là 180.921, giá lớn nhất là 755.000, giá nhỏ nhất là 34.900, rất may là nhìn sơ thì giá của các ngôi nhà hợp lệ, và không có giá trị nào nhỏ hơn 0.

# %%
train_data.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath     HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal       MoSold       YrSold      SalePrice
# ...

# %%
list_missing_value = train_data.columns[train_data.isnull().any()].to_list()
print(f"Có {len(list_missing_value)} cột bị thiếu dữ liệu trong tập train:")
print(list_missing_value)
# Out:
# Có 19 cột bị thiếu dữ liệu trong tập train:
# ['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']

# %%
test_data.describe()
# Out:
#         MSSubClass  LotFrontage       LotArea  OverallQual  OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath     HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal       MoSold       YrSold
# count  1459.000000  1232.000000   1459.000000  1459.000000  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  1458.000000  1458.000000  1458.000000  1459.000000  1459.000000   1459.000000  1459.000000   1457.000000   1457.000000  1459.000000  1459.000000   1459.000000   1459.000000   1459.000000  1459.00000  1381.000000  1458.000000  1458.000000  1459.000000  1459.000000    1459.000000  1459.000000  1459.000000  1459.000000   1459.000000  1459.000000  1459.000000
# ...

# %%
list_missing_value = test_data.columns[test_data.isnull().any()].to_list()
print(f"Có {len(list_missing_value)} cột bị thiếu dữ liệu trong tập test")
print(list_missing_value)
# Out:
# Có 33 cột bị thiếu dữ liệu trong tập test
# ['MSZoning', 'LotFrontage', 'Alley', 'Utilities', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType']

# %% [markdown]
# **Nhận xét:** Có những cột trong tập train không có dữ liệu khuyết nhưng trong tập test có dữ liệu khuyết.

# %% [markdown]
# ## 1.1 Phân tích biến numerical

# %% [markdown]
# ### 1.1.1 Phân tích độ tương quan

# %% [markdown]
# Nhóm vẽ ra đồ thị tương quan với các feature có abs(corr) > 0.5

# %%
# Create correlation matrix from train data - only numeric columns
numeric_columns = train_data.select_dtypes(include=['int64', 'float64'])
corr_mat = numeric_columns.corr()

# Select correlations greater than 0.5
high_corr_mat = corr_mat[abs(corr_mat) >= 0.5]

# Plot correlation heatmap
plt.figure(figsize=(18, 12))
sns.heatmap(high_corr_mat,
            annot=True,
            fmt='.1f',
            cmap='GnBu',
            vmin=0.5,
            vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Trong 36 numeric feature này, chỉ có một lượng có giá trị tuyệt đối của tương quan > 0.5 với SalePrice. Tuy nhiên, nhìn hình trên, có một vài cặp independent variable tương quan mạnh với nhau:
# - `TotalBsmtSF` - `1stFlrSF`: Diện tích của basement area ~ Diện tích của tầng 1.
# - `YearBuilt` - `GarageYrBlt`: Ngày nhà xây dựng ~ số năm mà cái Garage đã được sử dụng từ ngày xây dựng
# - `GrLivArea` - `TotRmsAbvGrd`: Tổng diện tích ngôi nhà từ mặt đất trở lên ~ Tổng số phòng trong nhà ngoại trừ phòng tắm từ tầng mặt đất trở lên.
# - `GarageCars` - `GarageArea`: Số lượng chiếc xe có thể để trong garage ~ kích thước garage
#
# Những biến này, ta sẽ bỏ đi 1 trong 2 vì biết được 1 biến ta có thể suy ra giá trị của biến còn lại, và tất nhiên ta sẽ giữ lại những biến nào có tương quan mạnh hơn với dependent variable. Đây gọi là vấn đề **multicolinearity**

# %% [markdown]
# **XOÁ NHỮNG BIẾN CÓ ĐỘ TƯƠNG QUAN CAO**

# %% [markdown]
# 1. Xóa 1 trong 2 biến: `TotalBsmtSF` - `1stFlrSF`

# %%
train_data[['TotalBsmtSF', '1stFlrSF','SalePrice']].corr()
# Out:
#              TotalBsmtSF  1stFlrSF  SalePrice
# TotalBsmtSF     1.000000  0.819530   0.613581
# 1stFlrSF        0.819530  1.000000   0.605852
# SalePrice       0.613581  0.605852   1.000000

# %%
X[['TotalBsmtSF', '1stFlrSF']].isnull().sum()
# Out:
# TotalBsmtSF    1
# 1stFlrSF       0
# dtype: int64

# %%
X = X.drop('1stFlrSF', axis = 1)

# %% [markdown]
# 2. Xóa 1 trong 2 biến: `YearBuilt` - `GarageYrBlt`

# %%
train_data[['YearBuilt', 'GarageYrBlt', 'SalePrice']].corr()
# Out:
#              YearBuilt  GarageYrBlt  SalePrice
# YearBuilt     1.000000     0.825667   0.522897
# GarageYrBlt   0.825667     1.000000   0.486362
# SalePrice     0.522897     0.486362   1.000000

# %%
X = X.drop('GarageYrBlt', axis = 1)

# %% [markdown]
# 3. Xóa 1 trong 2 biến: `GrLivArea` - `TotRmsAbvGrd`

# %%
train_data[['GrLivArea', 'TotRmsAbvGrd', 'SalePrice']].corr()
# Out:
#               GrLivArea  TotRmsAbvGrd  SalePrice
# GrLivArea      1.000000      0.825489   0.708624
# TotRmsAbvGrd   0.825489      1.000000   0.533723
# SalePrice      0.708624      0.533723   1.000000

# %%
X = X.drop('TotRmsAbvGrd', axis = 1)

# %% [markdown]
# 4. Xóa 1 trong 2 biến: `GarageCars` - `GarageArea`

# %%
train_data[['GarageCars', 'GarageArea', 'SalePrice']].corr()
# Out:
#             GarageCars  GarageArea  SalePrice
# GarageCars    1.000000    0.882475   0.640409
# GarageArea    0.882475    1.000000   0.623431
# SalePrice     0.640409    0.623431   1.000000

# %%
X = X.drop('GarageArea', axis = 1)

# %%
train_data = train_data.drop(['1stFlrSF', 'GarageYrBlt', 'TotRmsAbvGrd', 'GarageArea'], axis = 1)

# %% [markdown]
# ### 1.1.2 Phân tích độ phân phối

# %% [markdown]
# **a. `SalePrice` - Giá bán của ngôi nhà**

# %%
plt.figure(figsize=(4,3))
sns.distplot(y)
title = plt.title("House Price Distribution")

# %% [markdown]
# Dễ dàng nhận thấy phân phối SalePrice bị right-skewed. Tính thử 2 số liệu thống kê Skewness và Kurtosis.

# %%
print(f"""Skewness: {y.skew()}
Kurtosis: {y.kurt()}""")
# Out:
# Skewness: 1.8828757597682129
# Kurtosis: 6.536281860064529

# %% [markdown]
# Skewness là độ đo về tính đối xứng phân phối của dữ liệu.
# - Skewness = 0: normally distributed.
# - Skewness > 0: right skewed.
# - Skewness < 0: left skewed.
#
# Kurtosis là độ đo, đo chênh lệch giữa 2 đỉnh (peak) của phân phối đang xét so với phân phối chuẩn. Nếu peak càng cao thì ta nói data này có heavy-tailed, ngược lại ta nói data này light-tailed với dữ liệu.
# - Kurtosis = 3: được gọi là mesokurtic, gần với normally distributed.
# - Kurtosis < 3: playkurtic, nghĩa là có peak thấp hơn phân phối chuẩn.
# - Kurtosis > 3, leptokurtic, nghĩa là có peak cao hơn phân phối chuẩn.

# %% [markdown]
# **b. `OverallQual` - Chất lượng toàn bộ nội thất trong nhà**

# %% [markdown]
# Overall Quality là biến có tương quan nhất với SalePrice, và rõ ràng là OverallQual càng cao thì SalePrice càng cao.

# %%
plt.figure(figsize=(4,3))
sns.distplot(X['OverallQual'])
title = plt.title("House Price Distribution")

# %%
plt.figure(figsize=(5, 4))
sns.boxplot(x='OverallQual', y='SalePrice', data=train_data, palette='GnBu')
title = plt.title('House Price by Overall Quality')

# %% [markdown]
# **c. Living Area (`GrLivArea`) - Tổng diện tích ngôi nhà từ mặt đất trở lên**
# - GrLivArea sẽ không bao gồm diện tích garage, basement (tầng hầm)

# %%
def plotCorrelation(variables, remove_outliers=True):
    """
    Hàm cải tiến để phân tích tương quan giữa hai biến và hiển thị biểu đồ
    
    Cải tiến so với phiên bản cũ:
    1. Phát hiện và loại bỏ outliers để cải thiện hệ số tương quan
    2. Áp dụng biến đổi logarithm để tăng tính tuyến tính
    3. Hiển thị các biểu đồ đẹp hơn với nhãn và tiêu đề rõ ràng
    4. So sánh định lượng các phương pháp cải thiện tương quan
    
    Args:
        variables: Danh sách chứa tên hai biến cần phân tích
        remove_outliers: Có loại bỏ giá trị ngoại lai hay không
    """
    # Tạo bản sao dữ liệu để phân tích, tránh thay đổi dữ liệu gốc
    df = train_data[[variables[0], variables[1]]].copy()
    
    # === CẢI TIẾN 1: Hiển thị tương quan ban đầu để so sánh ===
    original_corr = df.corr().iloc[1, 0]
    print(f"Correlation ban đầu: {original_corr:.4f}")
    print(f"(Code cũ chỉ hiển thị giá trị này: {original_corr:.4f})")
    
    # === CẢI TIẾN 2: Loại bỏ outliers (giá trị ngoại lai) ===
    # Code cũ không có chức năng này, giúp cải thiện tương quan
    if remove_outliers:
        # Sử dụng quy tắc 3-sigma để phát hiện outliers
        # Loại bỏ các điểm nằm ngoài 3 lần độ lệch chuẩn
        for var in variables:
            mean = df[var].mean()
            std = df[var].std()
            df = df[(df[var] > mean - 3*std) & (df[var] < mean + 3*std)]
        
        # Hiển thị kết quả sau khi loại bỏ outliers
        improved_corr = df.corr().iloc[1, 0]
        print(f"Correlation sau khi loại bỏ outliers: {improved_corr:.4f}")
        print(f"Cải thiện: {improved_corr - original_corr:.4f}")
    
    # === CẢI TIẾN 3: Thử nghiệm biến đổi logarithm ===
    # Code cũ không có chức năng này, giúp tăng tính tuyến tính
    df_log = train_data[[variables[0], variables[1]]].copy()
    # Sử dụng log1p (log(1+x)) thay vì log(x) để tránh lỗi với giá trị 0
    df_log[f"Log_{variables[0]}"] = np.log1p(df_log[variables[0]])
    df_log[f"Log_{variables[1]}"] = np.log1p(df_log[variables[1]])
    log_corr = df_log[[f"Log_{variables[0]}", f"Log_{variables[1]}"]].corr().iloc[1, 0]
    print(f"Correlation sau biến đổi logarithm: {log_corr:.4f}")
    print(f"Cải thiện so với ban đầu: {log_corr - original_corr:.4f}")
    
    # === CẢI TIẾN 4: Biểu đồ với dữ liệu gốc nhưng đẹp hơn ===
    # Vẫn giữ kiểu biểu đồ jointplot như code cũ nhưng cải thiện trực quan
    g = sns.jointplot(
        x=df[variables[0]],
        y=df[variables[1]],
        kind='reg',  # Giữ nguyên loại biểu đồ regression như code cũ
        height=9,
        scatter_kws={'s': 9, 'alpha': 0.7},  # Thêm alpha để nhìn rõ mật độ điểm
        marginal_kws={'kde': True},
        ratio=4  # Cải thiện tỷ lệ giữa biểu đồ chính và biểu đồ lề
    )
    
    # === CẢI TIẾN 5: Thêm tiêu đề và nhãn rõ ràng ===
    # Code cũ không có phần này
    g.fig.suptitle(f"Mối quan hệ giữa {variables[0]} và {variables[1]}", y=1.05, fontsize=16)
    g.set_axis_labels(variables[0], variables[1], fontsize=12)
    
    # === CẢI TIẾN 6: Hiển thị thêm biểu đồ sau biến đổi logarithm ===
    # Code cũ chỉ có một biểu đồ
    plt.figure(figsize=(10, 10))
    g2 = sns.jointplot(
        x=df_log[f"Log_{variables[0]}"],
        y=df_log[f"Log_{variables[1]}"],
        kind='reg',
        height=9,
        scatter_kws={'s': 9, 'alpha': 0.7},
        marginal_kws={'kde': True},
        ratio=4
    )
    g2.fig.suptitle(f"Mối quan hệ giữa Log({variables[0]}) và Log({variables[1]})", y=1.05, fontsize=16)
    g2.set_axis_labels(f"Log({variables[0]})", f"Log({variables[1]})", fontsize=12)
    
    # Đảm bảo hiển thị đẹp
    plt.tight_layout()
    plt.show()

# Sử dụng hàm đã cải tiến
print("=== SO SÁNH VỚI CODE CŨ ===")
print("Code cũ chỉ hiển thị một giá trị tương quan và một biểu đồ đơn giản")
print("Code mới hiển thị nhiều giá trị tương quan, cải thiện biểu đồ, và thêm biến đổi logarithm")
print("============================================\n")
plotCorrelation(['GrLivArea', 'SalePrice'])
# Out:
# === SO SÁNH VỚI CODE CŨ ===
# Code cũ chỉ hiển thị một giá trị tương quan và một biểu đồ đơn giản
# Code mới hiển thị nhiều giá trị tương quan, cải thiện biểu đồ, và thêm biến đổi logarithm
# ...
#
# Correlation ban đầu: 0.7086
# (Code cũ chỉ hiển thị giá trị này: 0.7086)
# Correlation sau khi loại bỏ outliers: 0.6903
# Cải thiện: -0.0184
# Correlation sau biến đổi logarithm: 0.7303
# Cải thiện so với ban đầu: 0.0216

# %% [markdown]
# Living area có mối quan hệ tuyến tính với house price. Trên đồ thị scatter plot trên, chúng ta có thể phát hiện ***outliers*** trong data, đặc biệt là 2 ngôi nhà ở gốc bên phải với living area lớn hơn ***4000 sqft*** và giá thấp hơn ***$200,000***.

# %% [markdown]
# **d. Year Built (`YearBuilt`) - số năm được sử dụng**

# %%
plt.figure(figsize=(15, 6))
sns.scatterplot(x='YearBuilt', y='SalePrice', data=train_data)
title = plt.title('House Price by Year Built')

# %% [markdown]
# **Year Build** cũng đóng vai trò quan trọng trong việc dự đoán giá. Nhà càng mới thì sẽ có giá trung bình càng cao. Tuy nhiên có một vài ngôi nhà trước năm 1900 có giá cao.

# %% [markdown]
# **e. `YearRemodAdd` - Ngày sửa sang lại**

# %%
plt.figure(figsize=(15, 6))
sns.scatterplot(x='YearRemodAdd', y='SalePrice', data=train_data)
title = plt.title('House Price by Year Built')

# %% [markdown]
# **f. `TotalBsmtSF` - Tổng diện tích tầng hầm**

# %%
def plotCorrelation(variables):
    """
    1. Print correlation of two variables
    2. Create jointplot of two variables
    """
    # Print correlation
    print("Correlation: ", train_data[[variables[0],
                                       variables[1]]].corr().iloc[1, 0])

    # Create jointplot
    plt.figure(figsize=(6, 6))
    sns.jointplot(x = train_data[variables[0]],
                  y = train_data[variables[1]],
                  kind='reg',
                  height=9,

                  # sets the size of the scatter plot markers to 10 points.
                  scatter_kws={'s': 9}, 

                  #the marginal histograms should be displayed as kernel density estimates (KDE) instead of histograms.
                  marginal_kws={'kde': True})
    


plotCorrelation(['TotalBsmtSF', 'SalePrice'])
# Out:
# Correlation:  0.6135805515591943

# %% [markdown]
# **g. `FullBath` - Tổng số phòng tắm của ngôi nhà**

# %%
plt.figure(figsize=(4,3))
sns.distplot(X['FullBath'])
title = plt.title("House Price Distribution")

# %%
plt.figure(figsize=(4, 3))
sns.boxplot(x='FullBath', y='SalePrice', data=train_data, palette='GnBu')
title = plt.title('House Price by FullBath')

# %% [markdown]
# ## 1.2 Phân tích các biến Categorical

# %%
def visualizeCatFeature(feature, figsize=(12, 6), top_n=None):
    """
    Visualize the relationship between `SalePrice` and categorical feature using box plots
    
    Parameters:
    - feature: Tên cột categorical cần phân tích
    - figsize: Kích thước figure
    - top_n: Số lượng nhóm hiển thị (theo giá trung vị cao nhất)
    """
    # Tính toán giá trị trung vị và số lượng mẫu cho từng nhóm
    stats = train_data.groupby([feature])['SalePrice'].agg(['median', 'count']).reset_index()
    stats = stats.sort_values('median', ascending=False)
    
    # Giới hạn số lượng nhóm hiển thị nếu được chỉ định
    if top_n is not None and top_n < len(stats):
        featOrder = stats[:top_n][feature].values
    else:
        featOrder = stats[feature].values
    
    plt.figure(figsize=figsize)
    # Vẽ boxplot
    ax = sns.boxplot(x=feature,
                y='SalePrice',
                data=train_data[train_data[feature].isin(featOrder)],
                order=featOrder,
                palette='GnBu_r')
    
    # Thêm số lượng mẫu vào nhãn
    for i, box in enumerate(ax.artists):
        count = stats[stats[feature] == featOrder[i]]['count'].values[0]
        median = stats[stats[feature] == featOrder[i]]['median'].values[0]
        ax.annotate(f'n={count}\n${median:,.0f}',
                   (i, median),
                   ha='center', va='bottom',
                   fontweight='bold', color='darkblue',
                   xytext=(0, 10),
                   textcoords='offset points')
    
    plt.title(f'House Price by {feature}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
plt.figure(figsize=(12, 6))
visualizeCatFeature('Neighborhood')
title = plt.title('House Price by Neighborhood')
tick = plt.xticks(rotation=45)

# %%
plt.figure(figsize=(10, 3))
visualizeCatFeature('RoofMatl')
title = plt.title('House Price by Roof Material')

# %%
plt.figure(figsize=(8, 3))
visualizeCatFeature('KitchenQual')
title = plt.title('House Price by Kitchen Quality')

# %% [markdown]
# # 2. Data Processing

# %% [markdown]
# ## 2.1 Xử lý missing value

# %%
missing_data_count = X.isnull().sum()
missing_data_percent = X.isnull().sum() / len(X) * 100
missing_data = pd.DataFrame({
    'Count': missing_data_count,
    'Percent': missing_data_percent
})
missing_data = missing_data[missing_data.Count > 0]
missing_data.sort_values(by='Count', ascending=False, inplace=True)

# %%
missing_data.head(5)
# Out:
#              Count    Percent
# PoolQC        2909  99.657417
# MiscFeature   2814  96.402878
# Alley         2721  93.216855
# Fence         2348  80.438506
# MasVnrType    1766  60.500171

# %%
print(f"Có tổng cộng {len(missing_data)} thuộc tính bị thiếu dữ liệu")
print("Các thuộc tính đó là :\n", missing_data.index.values)
# Out:
# Có tổng cộng 32 thuộc tính bị thiếu dữ liệu
# Các thuộc tính đó là :
#  ['PoolQC' 'MiscFeature' 'Alley' 'Fence' 'MasVnrType' 'FireplaceQu'
#  'LotFrontage' 'GarageFinish' 'GarageQual' 'GarageCond' 'GarageType'
#  'BsmtCond' 'BsmtExposure' 'BsmtQual' 'BsmtFinType2' 'BsmtFinType1'
#  'MasVnrArea' 'MSZoning' 'BsmtFullBath' 'BsmtHalfBath' 'Functional'
#  'Utilities' 'Exterior2nd' 'Exterior1st' 'BsmtUnfSF' 'BsmtFinSF2'
#  'BsmtFinSF1' 'Electrical' 'KitchenQual' 'TotalBsmtSF' 'GarageCars'
#  'SaleType']

# %% [markdown]
# Trong 32 thuộc tính bị thiếu dữ liệu này, ta có 3 nhóm thuộc tính khác nhau về loại thuộc tính và giá trị định nghĩa của từng thuộc tính.
# - Nhóm 1: Biến categorical với NA nghĩa là `None`, không có.
# - Nhóm 2: Ngược lại với nhóm 1, biến categorical với NA không có nghĩa là `None`, không có nghĩa là không có.
# - Nhóm 3: Biến numerical với NA nghĩa là `0`, giá trị 0.

# %% [markdown]
# ### 2.1.1 Nhóm 1

# %% [markdown]
# Nhóm 1 bao gồm 15 thuộc tính: `PoolQC`, `MiscFeature`, `Alley`, `Fence`, `FireplaceQu`, `GarageCond`, `GarageFinish`, `GarageQual`, `GarageType`, `BsmtCond`, `BsmtExposure`, `BsmtQual`, `BsmtFinType2`, `BsmtFinType1`, `MasVnrType`.

# %%
group_1 = ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
           'GarageCond', 'GarageFinish' , 'GarageQual', 'GarageType',
           'BsmtCond',  'BsmtExposure', 'BsmtQual', 'BsmtFinType2',
           'BsmtFinType1', 'MasVnrType']
X[group_1] = X[group_1].fillna("None")
train_data[group_1] = train_data[group_1].fillna("None")

# %% [markdown]
# ### 2.1.2 Nhóm 2

# %% [markdown]
# Nhóm 2 bao gồm 8 thuộc tính: `MSZoning`, `Utilities`, `Functional`, `KitchenQual`, `Electrical`, `Exterior2nd`, `Exterior1st`, `SaleType`.

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='most_frequent')

group_2 = ['MSZoning', 'Utilities', 'Functional',
           'KitchenQual', 'Electrical', 'Exterior1st',
            'Exterior2nd', 'SaleType']

X[group_2] = pd.DataFrame(imputer.fit_transform(X[group_2]), index=X.index)
train_data[group_2] = pd.DataFrame(imputer.fit_transform(train_data[group_2]),
                                   index=train_data.index)

# %% [markdown]
# ### 2.1.3 Nhóm 3

# %% [markdown]
# Nhóm 3 bao gồm 8 thuộc tính: `GarageCars`, `TotalBsmtSF`, `BsmtUnfSF`, `BsmtFinSF2`, `BsmtFinSF1`, `MasVnrArea`, `BsmtFullBath`, `BsmtHalfBath`.

# %%
group_3 = ['GarageCars', 'TotalBsmtSF', 'BsmtUnfSF',
           'BsmtFinSF2', 'BsmtFinSF1', 'MasVnrArea',
           'BsmtFullBath', 'BsmtHalfBath']

X[group_3] = X[group_3].fillna(0)
train_data[group_3] = train_data[group_3].fillna(0)

# %%
X.LotFrontage = X.LotFrontage.fillna(X.LotFrontage.mean())
train_data.LotFrontage = train_data.LotFrontage.fillna(train_data.LotFrontage.mean())

# %%
print("Tổng các dòng dữ liệu trên toàn bộ data: ", sum(X.isnull().sum()))
print("Tổng các dòng dữ liệu trên tập train: ", sum(train_data.isnull().sum()))
# Out:
# Tổng các dòng dữ liệu trên toàn bộ data:  0
# Tổng các dòng dữ liệu trên tập train:  0

# %% [markdown]
# ## 2.2 Xử lý outliers
#
# Outliers là giá trị ngoại lệ (ngoại lai), dữ liệu gây nhiễu.
#
# Mô hình hồi quy rất nhạy cảm với nhiễu, nên chúng ta cần xử lý dữ liệu nhiễu một cách cẩn thận.
#
# [Tham khảo tại đây!](https://machinelearningcoban.com/tabml_book/ch_data_processing/process_outliers.html)

# %% [markdown]
# **a. `GrLivArea` - Tổng diện tích ngôi nhà từ mặt đất trở lên**

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='GrLivArea', y='SalePrice', data=train_data)
title = plt.title('House Price vs. Living Area')

# %%
train_data[(train_data['GrLivArea'] >4000) & (train_data['SalePrice'] < 200000)]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual Functional  Fireplaces FireplaceQu GarageType GarageFinish  GarageCars GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# Id
# ...

# %%
train_data[(train_data['GrLivArea'] >3500) & (train_data['SalePrice'] > 200000)]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual Functional  Fireplaces FireplaceQu GarageType GarageFinish  GarageCars GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# Id
# ...

# %% [markdown]
# Có thể dễ dàng thấy được 2 điểm outlier ở bên trên.

# %%
outlier_index = train_data[(train_data.GrLivArea > 4000)
                           & (train_data.SalePrice < 200000)].index
X.drop(outlier_index, axis=0, inplace=True)
y.drop(outlier_index, axis=0, inplace=True)

train_data.drop(outlier_index, axis=0, inplace=True)

# %% [markdown]
# **b. `TotalBsmtSF` - Tổng diện tích tầng hầm**

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='TotalBsmtSF', y='SalePrice', data=train_data)
title = plt.title('House Price vs. TotalBsmtSF')

# %% [markdown]
# **c. `Street` - Phân loại làn đường băng qua ngôi nhà**

# %%
X['Street'].unique()
# Out:
# array(['Pave', 'Grvl'], dtype=object)

# %%
plt.figure(figsize=(4, 3))
visualizeCatFeature('Street')
title = plt.title('House Price by Street')

# %%
def histogram_for_categorical_feature(feature):
  plt.figure(figsize=(4,3))
  counts = X[feature].value_counts()
  sns_plot = sns.countplot(x = X[feature])

  # Viết số lên cột, canh giữa mỗi cột
  for i, v in enumerate(counts.values):
      x_offset = sns_plot.patches[i].get_width() / 2
      y_offset = 0.1
      plt.text(sns_plot.patches[i].get_x() + x_offset, v + y_offset, str(v), ha='center')
  plt.title(f"{feature} Distribution")
  plt.show()

# %%
histogram_for_categorical_feature('Street')

# %% [markdown]
# Số lượng `Grvl` nhỏ rất hơn nhiều so với `Pave` trên toàn bộ dữ liệu (tập train và tập test).
#
# Liệu có thể gộp 2 cột này, và loại bỏ feature này đi được không?

# %% [markdown]
# Nhóm đã loại bỏ thử, chạy mô hình nhưng không cho kết quả khả quan, nên nhóm quyết định không loại bỏ feature này.

# %%
# X.drop('Street', axis = 1, inplace = True)

# %% [markdown]
# **d. `LandContour` - Độ bằng phẳng của ngôi nhà**

# %%
histogram_for_categorical_feature('LandContour')

# %%
plt.figure(figsize=(4, 3))
visualizeCatFeature('LandContour')
title = plt.title('House Price by LandContour')

# %%
train_data[(train_data['LandContour'] == 'Lvl') & (train_data['SalePrice'] > 650000)]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual Functional  Fireplaces FireplaceQu GarageType GarageFinish  GarageCars GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# Id
# ...

# %%
train_data[(train_data['LandContour'] == 'Lvl') & (train_data['SalePrice'] == 200000)]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual Functional  Fireplaces FireplaceQu GarageType GarageFinish  GarageCars GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# Id
# ...

# %% [markdown]
# Những điểm được cho là outlier trên đồ thị `House Price By LandContour` trên ở cột `Lvl` không phải là outlier, mà giá cao bị chi phối bởi nhiều feature khác. Như phân tích liền kề bên trên, đa số giá cao do LotGrontage và LotArea lớn hơn nhiều.

# %% [markdown]
# ## 2.3 Feature Engineering

# %% [markdown]
# ### 2.3.1 Tạo các biến mới

# %%
# X['totalSqFeet'] = X['TotalBsmtSF'] + X['1stFlrSF'] + X['2ndFlrSF']
# X['totalBathroom'] = X.FullBath + X.BsmtFullBath + 0.5 * (X.HalfBath + X.BsmtHalfBath)
# X['houseAge'] = X.YrSold - X.YearBuilt
# X['reModeled'] = np.where(X.YearRemodAdd == X.YearBuilt, 0, 1)
# X['isNew'] = np.where(X.YrSold == X.YearBuilt, 1, 0)

# %% [markdown]
# ### 2.3.2 Label Encoding

# %% [markdown]
# Dùng cho các biến ordinal categorical, nhắm chuẩn hóa về số.

# %%
from sklearn.preprocessing import LabelEncoder


# Apply Label Encoder
label_encoder = LabelEncoder()
label_encoding_cols = [
    "Alley", "BsmtCond", "BsmtExposure", "BsmtFinType1", "BsmtFinType2",
    "BsmtQual", "ExterCond", "ExterQual", "FireplaceQu", "Functional",
    "GarageCond", "GarageQual", "HeatingQC", "KitchenQual", "LandSlope",
    "LotShape", "PavedDrive", "PoolQC", "Street", "Utilities"
]

for col in label_encoding_cols:
  X[col] = label_encoder.fit_transform(X[col])

# %% [markdown]
# ### 2.3.3 Biến đổi numerical variable sang categorical variable

# %% [markdown]
# `YrSold` có thể tác động lớn tới giá (ví dụ năm đó khủng hoảng kinh tế, chiến tranh,...giá nhà có thể thấp). Do đó, ta chuyển chúng sang dạng categorical.
#
# `MoSold`, `MSSubClass` là những biến numeric nhưng không có ý nghĩa gì về mặt thứ tự nên ta chuyển nó sang dạng categorical.

# %%
to_factor_cols = ['YrSold', 'MoSold', 'MSSubClass']

for col in to_factor_cols:
    X[col] = X[col].apply(str)

# %% [markdown]
# ### 2.3.4 Skewness và chuẩn hoá dữ liệu

# %% [markdown]
# **Target variable**

# %%
from scipy import stats
from scipy.stats import norm

# %%
def normality_plot(X):
    """
    1. Draw distribution plot with normal distribution fitted curve
    2. Draw Quantile-Quantile plot 
    """
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))

    sns.distplot(X, fit=norm, ax=axes[0])
    axes[0].set_title('Distribution Plot')

    axes[1] = stats.probplot((X), plot=plt)
    plt.tight_layout()

# %%
normality_plot(y)

# %% [markdown]
# Một trong những cách để normalize right-skewd data là dùng log transformation vì giá trị lớn sẽ bị kéo về giữa, tuy nhiên log(0) = nan, nên tôi dùng log(1+x).

# %%
y = np.log(1 + y)

# %%
normality_plot(y)

# %% [markdown]
# Bước tiếp theo, kiểm tra skewness của các numerical variable còn lại và dùng log transformation để chuẩn hóa.
# - Nếu skewness <= -1 or >= 1, thì phân phối bị highly skewed.
# - Nếu skewness nằm giữa -1 và -0.5 hoặc 0.5 và 1 thì phân phối bị moderately skewed.
# - Nếu skewness nằm giữa -0.5 và 0.5 thì phân phối approximately symmetric.

# %%
# Chỉ tính skew cho các cột số
numeric_columns = train_data.select_dtypes(include=['int64', 'float64'])
skewness = numeric_columns.skew().sort_values(ascending=False)
skewness[abs(skewness) > 0.5]
# Out:
# MiscVal          24.460085
# PoolArea         15.948945
# LotArea          12.573925
# 3SsnPorch        10.297106
# LowQualFinSF      9.004955
# KitchenAbvGr      4.484883
# BsmtFinSF2        4.251925
# ScreenPorch       4.118929
# BsmtHalfBath      4.100114
# EnclosedPorch     3.087164
# MasVnrArea        2.696329
# OpenPorchSF       2.339829
# SalePrice         1.881296
# LotFrontage       1.694720
# WoodDeckSF        1.545805
# MSSubClass        1.407011
# GrLivArea         1.010992
# BsmtUnfSF         0.920903
# 2ndFlrSF          0.812957
# BsmtFinSF1        0.764789
# OverallCond       0.691035
# HalfBath          0.680051
# Fireplaces        0.632060
# BsmtFullBath      0.590358
# TotalBsmtSF       0.511703
# YearRemodAdd     -0.501838
# YearBuilt        -0.612295
# dtype: float64

# %%
# List of skewed columns
skewed_cols = list(skewness[abs(skewness) > 0.5].index)

# Remove 'MSSubClass' and 'SalePrice'
skewed_cols = [
    col for col in skewed_cols if col not in ['MSSubClass', 'SalePrice']
]

# Log-transform skewed columns
for col in skewed_cols:
    X[col] = np.log(1 + X[col])

# %%
normality_plot(X.GrLivArea)

# %% [markdown]
# ### 2.3.5 Feature Scaling

# %% [markdown]
# Ngoại trừ Decision Tree và Random Forest, các thuật toán còn lại trong machine learning nên được standardize để mô hình nhanh hội tụ và ổn định.

# %%
from sklearn.preprocessing import RobustScaler
numerical_cols = list(X.select_dtypes(exclude=['object']).columns)
scaler = RobustScaler()
X[numerical_cols] = scaler.fit_transform(X[numerical_cols])

# %%
X.shape
# Out:
# (2917, 75)

# %% [markdown]
# ### 2.3.6 One-hot encoding

# %% [markdown]
# Khi chuyển các biến categorical sang one hot encoding, thì nhóm xóa luôn cột đặc trưng gốc, với drop_first = True.

# %%
X = pd.get_dummies(X, drop_first=True)
print("X.shape:", X.shape)
# Out:
# X.shape: (2917, 228)

# %% [markdown]
# # 3. Ghi dữ liệu ra file mới

# %% [markdown]
# Sau khi tiền xử lý, ta chia data lại như ban đầu, tập train và test.

# %%
ntest = len(test_data)
ntest
# Out:
# 1459

# %%
X_train = X.iloc[:-ntest, :]
X_test = X.iloc[-ntest:, :]
print("X_train.shape:", X_train.shape)
print("X_test.shape:", X_test.shape)
# Out:
# X_train.shape: (1458, 228)
# X_test.shape: (1459, 228)

# %% [markdown]
# Chuẩn hóa cột đặc trưng SalePrice với hàm log

# %%
X_train['SalePrice'] = np.log(1 + train_data['SalePrice'])

# %% [markdown]
# Cuối cùng, sau khi đã hoàn thành quá trình tiền xử lý, ta sẽ ghi dữ liệu ra 2 file dữ liệu là `train_official.csv` và `test_official.csv`

# %%
X_train.to_csv("train_official.csv")
X_test.to_csv("test_official.csv")
